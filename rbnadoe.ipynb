# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import warnings

from sklearn.preprocessing import LabelEncoder
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('dog.csv')
print(df)
# Out:
#       edge_count  tab_switchcount  shift_count  alt_count  ctrl_count  \
# 0              0                0            0          0           3
# 1             12                0            0          0           0
# 2             10                0            0          0           0
# 3              0                2            4          0           5
# 4             10                0            0          0           0
# ...          ...              ...          ...        ...         ...
# 2995           0                1            0          0           4
# 2996           0                0            0          7           0
# 2997          16                0            0          7           0
# 2998           0                0            7          0           6
# 2999           0                0            0          4           4
#
#       meta_count  copy_count  paste_count  resize_count  char_key  ...  \
# 0              0           4            0             0        25  ...
# 1              5           0            3             0        17  ...
# 2              0           0            0            13         0  ...
# 3              0           0            0             0        23  ...
# 4              0           1            5             0        19  ...
# ...          ...         ...          ...           ...       ...  ...
# 2995           0           4            4             0         0  ...
# 2996           0           0            0            13        19  ...
# 2997           1           0            3            14        26  ...
# 2998           0           5            0             0        22  ...
# 2999           4           0            0             0         0  ...
#
#       para_edge  sus_keys  ss_count  meta_key  tab_switch  clip_count  \
# 0         0.000      0.18         0       0.0    0.000000         0.4
# 1         0.012      0.00         0       0.5    0.000000         0.3
# 2         0.010      0.00         0       0.0    0.000000         0.0
# 3         0.000      0.34         0       0.0    0.166667         0.0
# 4         0.010      0.00         0       0.0    0.000000         0.6
# ...         ...       ...       ...       ...         ...         ...
# 2995      0.000      0.08         0       0.0    0.083333         0.8
# 2996      0.000      0.14         0       0.0    0.000000         0.0
# 2997      0.016      0.14         0       0.1    0.000000         0.3
# 2998      0.000      0.12         0       0.0    0.000000         0.5
# 2999      0.000      0.16         0       0.4    0.000000         0.0
#
#       sus_resize  sus_blur  char_sus      risk
# 0       0.000000  0.000000         0  0.580000
# 1       0.000000  0.313050         0  1.125050
# 2       0.442000  0.173205         0  0.625205
# 3       0.000000  0.000000         0  0.506667
# 4       0.000000  0.000000         0  0.610000
# ...          ...       ...       ...       ...
# 2995    0.000000  0.000000         0  0.963333
# 2996    0.433333  0.400000         0  0.973333
# 2997    0.481600  0.000000         0  1.037600
# 2998    0.000000  0.381051         0  1.001051
# 2999    0.000000  0.242487         0  0.802487
#
# [3000 rows x 26 columns]

# %%
df = df.drop(["red_edge", "para_edge", "sus_keys", "ss_count", "meta_key", "tab_switch", "clip_count", "sus_resize", "sus_blur", "char_sus"], axis=1)
X = df.drop('risk',axis= 1) 
y = df['risk'] 

print(y)
# Out:
# 0       0.580000
# 1       1.125050
# 2       0.625205
# 3       0.506667
# 4       0.610000
#           ...
# 2995    0.963333
# 2996    0.973333
# 2997    1.037600
# 2998    1.001051
# 2999    0.802487
# Name: risk, Length: 3000, dtype: float64

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder


label_encoder = LabelEncoder()
x_categorical = df.select_dtypes(include=['object']).apply(label_encoder.fit_transform)
x_numerical = df.select_dtypes(exclude=['object']).values
x = pd.concat([pd.DataFrame(x_numerical), x_categorical], axis=1).values

regressor = RandomForestRegressor(n_estimators=10, random_state=0, oob_score=True)

regressor.fit(x, y)
# Out:
# RandomForestRegressor(n_estimators=10, oob_score=True, random_state=0)

# %%
from sklearn.metrics import mean_squared_error, r2_score

oob_score = regressor.oob_score_
print(f'Out-of-Bag Score: {oob_score}')

predictions = regressor.predict(x)

mse = mean_squared_error(y, predictions)
print(f'Mean Squared Error: {mse}')

r2 = r2_score(y, predictions)
print(f'R-squared: {r2}')
# Out:
# Out-of-Bag Score: 0.9368393362626921
# Mean Squared Error: 5.289552213143486e-06
# R-squared: 0.9999623787652937
